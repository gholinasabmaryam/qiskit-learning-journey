# %% [markdown]
# # **U, R(Φ), S & T Gate**

# %% [markdown]
# ## U Gate

# %% [markdown]
# ### drawing

# %%
from qiskit import *
from math import pi
import numpy as np

qc= QuantumCircuit(3,0) #(Q,C) Q: number of qubits / C: number of classic bits
#initial state
initialstate= [0,0,0,0,0,0,1,1] #putting the amplitude of the basis gates: |000⟩=0 , |001⟩=0 , |010⟩=0 , |011⟩=0 , |100⟩=0 , |101⟩=0 , |110⟩=1 , |111⟩=1 
norm=np.linalg.norm(initialstate) #normalizating the initialstate
vector= initialstate/norm
qc.initialize(vector)



qc.u(pi/4,pi/2,0,0) #(Dy,Dz,Dz,Q) rotating around the specified axis with the degree of D on the qubit of Q (Due to euler rotation matrix)
#qc.measure(0,0) #if I do the measuring then the bloch sphere won't change anything due to collapsing
qc.u(pi/4,0,-pi/2,1)
qc.u(pi/4,pi/2,-pi/2,2) #rotation around x with the degree of theta is made by qc.u(theta,pi/2,-pi/2,2)


qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# %% [markdown]
# ## R(Φ) Gate

# %% [markdown]
# ### Drawing

# %%
from qiskit import *
from math import pi

qc= QuantumCircuit(3,0) #(Q,C) Q: number of qubits / C: number of classic bits

qc.rz(pi/2,0) #(D,Q) rotating around z axis with the degree of D on the qubit of Q
#qc.measure(0,0) #if I do the measuring then the bloch sphere won't change anything due to collapsing
qc.rx(pi/2,1)
qc.ry(pi/2,2)


qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# %% [markdown]
# ## S Gate

# %% [markdown]
# ### Drawing

# %%
# Rz(Φ=PI/2)=S gate / (SS =Z= Rz(Φ=PI))

from qiskit import *
import numpy as np


qc= QuantumCircuit(3,0) #(Q,C) Q: number of qubits / C: number of classic bits
#initial state
initialstate= [1,1,1,1,1,1,1,1] #putting the amplitude of the basis gates: |000⟩=0 , |001⟩=0 , |010⟩=0 , |011⟩=0 , |100⟩=0 , |101⟩=0 , |110⟩=1 , |111⟩=1 
norm=np.linalg.norm(initialstate) #normalizating the initialstate
vector= initialstate/norm
qc.initialize(vector)

qc.s(0) 
qc.sdg(1)

#SS† =I ->
qc.s(2) 
qc.sdg(2)

qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# %% [markdown]
# ## T Gate

# %% [markdown]
# ### Drawing

# %%
# Rz(Φ=PI/4)=T gate / (TTTT =SS = Z= Rz(Φ=PI))

from qiskit import *
import numpy as np


qc= QuantumCircuit(3,0) #(Q,C) Q: number of qubits / C: number of classic bits
#initial state
initialstate= [1,1,1,1,1,1,1,1] #putting the amplitude of the basis gates :|000⟩=0 , |001⟩=0 , |010⟩=0 , |011⟩=0 , |100⟩=0 , |101⟩=0 , |110⟩=1 , |111⟩=1 
vector= initialstate/norm
qc.initialize(vector)

qc.t(0) 
qc.tdg(1)

#TT† =I ->
qc.t(2) 
qc.tdg(2)

qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer
from qiskit_textbook.tools import array_to_latex

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
array_to_latex(statevector,pretext="\\text{Statevector}= ")

counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)
# Out:
# $\displaystyle
# \text{Statevector}= \begin{bmatrix}
# \tfrac{1}{\sqrt{8}} \\
# \tfrac{1}{4}(1 + i) \\
# \tfrac{1}{4}(1 - i) \\
# \tfrac{1}{\sqrt{8}} \\
# \tfrac{1}{\sqrt{8}} \\
# \tfrac{1}{4}(1 + i) \\
# \tfrac{1}{4}(1 - i) \\
# \tfrac{1}{\sqrt{8}}
# \end{bmatrix}
# $
