# %% [markdown]
# # **Swap Gate**

# %% [markdown]
# ## Swap Function

# %%
from qiskit import *
from math import pi
import numpy as np

qc= QuantumCircuit(2,0) #(Q,C) Q: number of qubits / C: number of classic bits
#initial state
initialstate= [0,0,1,0] #putting the amplitude of the basis gates e.g. for 2 qubits: |00>=0 ,|01>=0  ,|10>=1 , |11>=0
norm=np.linalg.norm(initialstate) #normalizating the initialstate
vector= initialstate/norm
qc.initialize(vector)

qc.swap(0,1) # swap gate 


qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# as you can see |01> swaps to |10>

# %% [markdown]
# ## Swap Gate Using Standard Gate(CNOT)

# %%
from qiskit import *
from math import pi
import numpy as np

qc= QuantumCircuit(2,0) #(Q,C) Q: number of qubits / C: number of classic bits
#initial state
initialstate= [0,0,1,0] #putting the amplitude of the basis gates e.g. for 2 qubits: |00>=0 ,|01>=0  ,|10>=1 , |11>=0
norm=np.linalg.norm(initialstate) #normalizating the initialstate
vector= initialstate/norm
qc.initialize(vector)

qc.cx(0,1)  
qc.cx(1,0)
qc.cx(0,1)



qc.draw('mpl')

# %% [markdown]
# ### Bloch Sphere

# %%
from qiskit_aer import Aer

# we use statevector_simulator to see the wavefunction (exact quantum state) but we use AerSimulator() to simulate real measurements and results like from an actual quantum computer.

#running the circuit (exact quantum states)
backend = Aer.get_backend('statevector_simulator')
job = backend.run(qc) 
result = job.result()


#statevectorS
statevector = result.get_statevector() #gives what basisvecor* amplitude are in the result
counts = result.get_counts() #the result is always backward of the circuits e.g. 01 = 0 for 2nd qubit & 1 for 1st qubit

#the statevector feature is needed to illustrate the vectors on a bloch sphere
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(statevector)

# as you can see |01> swaps to |10> (same result)
